# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import GridSearchCV, cross_val_score, StratifiedKFold
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier, VotingClassifier
from sklearn.metrics import accuracy_score

# %%
knn_params = {
    'n_neighbors': range(1, 21, 2),
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan', 'minkowski']
}

svm_params = {
    'C': [0.1, 1, 10, 100],
    'kernel': ['linear', 'rbf'],
    'gamma': ['scale', 'auto']
}

def load_data(video_name):
    data_files = [
        f"{video_name}_DataRGB.csv",
        f"{video_name}_DataHOG.csv",
        f"{video_name}_DataH10.csv",
        f"{video_name}_DataLBP.csv",
    ]
    labels_file = f"{video_name}_Labels.csv"

    data = [pd.read_csv(file) for file in data_files]
    labels = pd.read_csv(labels_file)

    return data, labels

def split_data(data, labels, training_size):
    X_train = data.iloc[:training_size, :]
    X_test = data.iloc[training_size:, :]
    y_train = labels.iloc[:training_size, :]
    y_test = labels.iloc[training_size:, :]

    return X_train, X_test, y_train, y_test

def preprocess_data(X_train, X_test):
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)

    return X_train_scaled, X_test_scaled

def class_distribution(y_train):
    return y_train.value_counts(normalize=True)

def compare_results(video_name, feature_name, results_df):
    ground_truth_file = f"{video_name}_Results.csv"
    ground_truth_results = pd.read_csv(ground_truth_file, header=None, sep=",")

    mean_ground_truth = ground_truth_results.mean(axis=0)
    std_ground_truth = ground_truth_results.std(axis=0)

    print(f"\nGround truth results for {video_name} using {feature_name} features:")
    print(f"Mean: {mean_ground_truth.values[0]:.4f}")
    print(f"Standard Deviation: {std_ground_truth.values[0]:.4f}")

    mean_code_results = results_df['Accuracy'].mean()
    std_code_results = results_df['Accuracy'].std()

    print(f"\nCode results for {video_name} using {feature_name} features:")
    print(f"Mean: {mean_code_results:.4f}")
    print(f"Standard Deviation: {std_code_results:.4f}")

def largest_prior_classifier(y_train):
    return y_train.value_counts().idxmax()

def predict_largest_prior(y_train, X_test):
    largest_prior = largest_prior_classifier(y_train)
    return np.full(X_test.shape[0], largest_prior)

def train_and_evaluate_classifiers(X_train, X_test, y_train, y_test, knn_tuned, svm_tuned):
    classifiers = [
        ('Largest Prior', None),
        ('Linear Discriminant Analysis', LinearDiscriminantAnalysis()),
        ('3-nn', KNeighborsClassifier(n_neighbors=3)),
        ('Decision Tree', DecisionTreeClassifier(random_state=42)),
        ('SVM', SVC(random_state=42)),
        ('Bagging', BaggingClassifier(random_state=42)),
        ('Random Forest', RandomForestClassifier(random_state=42)),
        ('KNN (tuned)', knn_tuned),
        ('SVM (tuned)', svm_tuned)
    ]

    results = []

    largest_prior_accuracy = y_test.value_counts(normalize=True).max()
    results.append({'Classifier': 'Largest Prior', 'Accuracy': largest_prior_accuracy})

    for name, classifier in classifiers[1:]:
        if name == 'Ensemble':
            y_pred = ensemble_voting_classifier(classifiers[1:], X_train, y_train, X_test)
        else:
            classifier.fit(X_train, y_train.values.ravel())
            y_pred = classifier.predict(X_test)

        accuracy = accuracy_score(y_test, y_pred)
        results.append({'Classifier': name, 'Accuracy': accuracy})

    results_df = pd.DataFrame(results)
    return results_df

def apply_pca(X_train, X_test, n_components=0.95):
    pca = PCA(n_components=n_components)
    X_train_pca = pca.fit_transform(X_train)
    X_test_pca = pca.transform(X_test)
    return X_train_pca, X_test_pca

def hyperparameter_tuning(classifier, param_grid, X_train, y):
    cv = StratifiedKFold(n_splits=5)
    grid_search = GridSearchCV(classifier, param_grid, cv=cv, scoring='accuracy')
    grid_search.fit(X_train, y.values.ravel())
    best_estimator = grid_search.best_estimator_
    return best_estimator

def ensemble_voting_classifier(classifiers, X_train, y_train, X_test):
    voting_clf = VotingClassifier(estimators=classifiers, voting='hard', n_jobs=-1)
    voting_clf.fit(X_train, y_train.values.ravel())
    y_pred = voting_clf.predict(X_test)
    return y_pred

# Main loop
if __name__ == "__main__":
    video_info = {
        'Pigs_49651_960_540_500f': 2710,
        'Koi_5652_952_540': 916,
        'Pigeons_8234_1280_720': 2268,
        'Pigeons_4927_960_540_600f': 1574,
        'Pigeons_29033_960_540_300f': 2148
    }

    feature_names = ['DataRGB', 'DataHOG', 'DataH10', 'DataLBP']

    for video_name, training_size in video_info.items():
        print(f'Processing {video_name}')
        data, labels = load_data(video_name)
        for i, feature_data in enumerate(data):
            feature_name = feature_names[i]
            print(f'\nFeature: {feature_name}')
            X_train_temp, X_test_temp, y_train_temp, y_test_temp = split_data(feature_data, labels, training_size)
            X_train_scaled, X_test_scaled = preprocess_data(X_train_temp, X_test_temp)

            # Apply PCA
            X_train_pca, X_test_pca = apply_pca(X_train_scaled, X_test_scaled)

            # Check class distribution
            print(f'Class Distribution:\n{class_distribution(y_train_temp)}\n')

            knn_tuned = hyperparameter_tuning(KNeighborsClassifier(), knn_params, X_train_pca, y_train_temp)
            svm_tuned = hyperparameter_tuning(SVC(probability=True), svm_params, X_train_pca, y_train_temp)

            # Perform cross-validation
            cv_scores_knn = cross_val_score(knn_tuned, X_train_pca, y_train_temp.values.ravel(), cv=StratifiedKFold(n_splits=5))
            cv_scores_svm = cross_val_score(svm_tuned, X_train_pca, y_train_temp.values.ravel(), cv=StratifiedKFold(n_splits=5))
            print(f"Cross-validation scores for KNN: {cv_scores_knn}")
            print(f"Cross-validation scores for SVM: {cv_scores_svm}")

            # Evaluate classifiers
            results_df = train_and_evaluate_classifiers(X_train_pca, X_test_pca, y_train_temp, y_test_temp, knn_tuned, svm_tuned)
            print(results_df)

            # Compare results with ground truth
            compare_results(video_name, feature_name, results_df)

        print('\n')
# Out:
# Processing Pigs_49651_960_540_500f
#
# Feature: DataRGB
# Class Distribution:
# 16
# 17    0.089299
# 16    0.088561
# 10    0.085609
# 1     0.077860
# 11    0.073432
# 2     0.066790
# 12    0.063469
# 9     0.060148
# 18    0.053875
# 7     0.050923
# 6     0.049077
# 13    0.047601
# 5     0.047232
# 4     0.030627
# 14    0.028782
# 8     0.018819
# 20    0.014760
# 15    0.014022
# 0     0.013653
# 19    0.013284
# 3     0.007380
# 21    0.004797
# dtype: float64
#
# Cross-validation scores for KNN: [0.41328413 0.60701107 0.71217712 0.79151292 0.6697417 ]
# Cross-validation scores for SVM: [0.4298893  0.62546125 0.77859779 0.82287823 0.65682657]
#                      Classifier  Accuracy
# 0                 Largest Prior  0.075677
# 1  Linear Discriminant Analysis  0.222049
# 2                          3-nn  0.244784
# 3                 Decision Tree  0.162255
# 4                           SVM  0.254438
# 5                       Bagging  0.201806
# 6                 Random Forest  0.252881
# 7                   KNN (tuned)  0.249455
# 8                   SVM (tuned)  0.253815
#
# Ground truth results for Pigs_49651_960_540_500f using DataRGB features:
# Mean: 0.2456
# Standard Deviation: 0.0837
#
# Code results for Pigs_49651_960_540_500f using DataRGB features:
# Mean: 0.2130
# Standard Deviation: 0.0602
#
# Feature: DataHOG
# Class Distribution:
# 16
# 17    0.089299
# 16    0.088561
# 10    0.085609
# 1     0.077860
# 11    0.073432
# 2     0.066790
# 12    0.063469
# 9     0.060148
# 18    0.053875
# 7     0.050923
# 6     0.049077
# 13    0.047601
# 5     0.047232
# 4     0.030627
# 14    0.028782
# 8     0.018819
# 20    0.014760
# 15    0.014022
# 0     0.013653
# 19    0.013284
# 3     0.007380
# 21    0.004797
# dtype: float64
#
# Cross-validation scores for KNN: [0.31365314 0.64575646 0.68081181 0.80627306 0.60516605]
# Cross-validation scores for SVM: [0.28413284 0.6697417  0.72324723 0.81180812 0.51660517]
#                      Classifier  Accuracy
# 0                 Largest Prior  0.075677
# 1  Linear Discriminant Analysis  0.221738
# 2                          3-nn  0.213018
# 3                 Decision Tree  0.115229
# 4                           SVM  0.230769
# 5                       Bagging  0.147929
# 6                 Random Forest  0.161320
# 7                   KNN (tuned)  0.222672
# 8                   SVM (tuned)  0.232326
#
# Ground truth results for Pigs_49651_960_540_500f using DataHOG features:
# Mean: 0.2456
# Standard Deviation: 0.0837
#
# Code results for Pigs_49651_960_540_500f using DataHOG features:
# Mean: 0.1801
# Standard Deviation: 0.0575
#
# Feature: DataH10
# Class Distribution:
# 16
# 17    0.089299
# 16    0.088561
# 10    0.085609
# 1     0.077860
# 11    0.073432
# 2     0.066790
# 12    0.063469
# 9     0.060148
# 18    0.053875
# 7     0.050923
# 6     0.049077
# 13    0.047601
# 5     0.047232
# 4     0.030627
# 14    0.028782
# 8     0.018819
# 20    0.014760
# 15    0.014022
# 0     0.013653
# 19    0.013284
# 3     0.007380
# 21    0.004797
# dtype: float64
#
# Cross-validation scores for KNN: [0.34501845 0.45756458 0.46678967 0.45202952 0.4298893 ]
# Cross-validation scores for SVM: [0.29335793 0.48154982 0.48523985 0.54428044 0.41512915]
#                      Classifier  Accuracy
# 0                 Largest Prior  0.075677
# 1  Linear Discriminant Analysis  0.218312
# 2                          3-nn  0.173155
# 3                 Decision Tree  0.171909
# 4                           SVM  0.204298
# 5                       Bagging  0.182809
# 6                 Random Forest  0.193709
# 7                   KNN (tuned)  0.201183
# 8                   SVM (tuned)  0.234195
#
# Ground truth results for Pigs_49651_960_540_500f using DataH10 features:
# Mean: 0.2456
# Standard Deviation: 0.0837
#
# Code results for Pigs_49651_960_540_500f using DataH10 features:
# Mean: 0.1839
# Standard Deviation: 0.0454
#
# Feature: DataLBP
# Class Distribution:
# 16
# 17    0.089299
# 16    0.088561
# 10    0.085609
# 1     0.077860
# 11    0.073432
# 2     0.066790
# 12    0.063469
# 9     0.060148
# 18    0.053875
# 7     0.050923
# 6     0.049077
# 13    0.047601
# 5     0.047232
# 4     0.030627
# 14    0.028782
# 8     0.018819
# 20    0.014760
# 15    0.014022
# 0     0.013653
# 19    0.013284
# 3     0.007380
# 21    0.004797
# dtype: float64
#
# Cross-validation scores for KNN: [0.1402214  0.37822878 0.47232472 0.48154982 0.35239852]
# Cross-validation scores for SVM: [0.13099631 0.43542435 0.51476015 0.55535055 0.32103321]
#                      Classifier  Accuracy
# 0                 Largest Prior  0.075677
# 1  Linear Discriminant Analysis  0.152289
# 2                          3-nn  0.119589
# 3                 Decision Tree  0.105886
# 4                           SVM  0.146683
# 5                       Bagging  0.128620
# 6                 Random Forest  0.139209
# 7                   KNN (tuned)  0.137963
# 8                   SVM (tuned)  0.147618
#
# Ground truth results for Pigs_49651_960_540_500f using DataLBP features:
# Mean: 0.2456
# Standard Deviation: 0.0837
#
# Code results for Pigs_49651_960_540_500f using DataLBP features:
# Mean: 0.1282
# Standard Deviation: 0.0246
#
#
# Processing Koi_5652_952_540
#
# Feature: DataRGB
# Class Distribution:
# 2
# 4    0.209607
# 5    0.155022
# 6    0.139738
# 8    0.108079
# 7    0.102620
# 1    0.090611
# 0    0.081878
# 2    0.057860
# 3    0.054585
# dtype: float64
#
# Cross-validation scores for KNN: [0.82608696 0.83606557 0.80327869 0.81967213 0.55191257]
# Cross-validation scores for SVM: [0.81521739 0.95628415 0.90163934 0.86885246 0.54644809]
#                      Classifier  Accuracy
# 0                 Largest Prior  0.222841
# 1  Linear Discriminant Analysis  0.374652
# 2                          3-nn  0.261838
# 3                 Decision Tree  0.231198
# 4                           SVM  0.292479
# 5                       Bagging  0.214485
# 6                 Random Forest  0.201950
# 7                   KNN (tuned)  0.249304
# 8                   SVM (tuned)  0.292479
#
# Ground truth results for Koi_5652_952_540 using DataRGB features:
# Mean: 0.2740
# Standard Deviation: 0.1284
#
# Code results for Koi_5652_952_540 using DataRGB features:
# Mean: 0.2601
# Standard Deviation: 0.0536
#
# Feature: DataHOG
# Class Distribution:
# 2
# 4    0.209607
# 5    0.155022
# 6    0.139738
# 8    0.108079
# 7    0.102620
# 1    0.090611
# 0    0.081878
# 2    0.057860
# 3    0.054585
# dtype: float64
#
# Cross-validation scores for KNN: [0.53804348 0.55737705 0.53551913 0.66120219 0.45355191]
# Cross-validation scores for SVM: [0.46195652 0.67759563 0.55191257 0.49180328 0.53005464]
#                      Classifier  Accuracy
# 0                 Largest Prior  0.222841
# 1  Linear Discriminant Analysis  0.114206
# 2                          3-nn  0.083565
# 3                 Decision Tree  0.108635
# 4                           SVM  0.091922
# 5                       Bagging  0.094708
# 6                 Random Forest  0.080780
# 7                   KNN (tuned)  0.073816
# 8                   SVM (tuned)  0.091922
#
# Ground truth results for Koi_5652_952_540 using DataHOG features:
# Mean: 0.2740
# Standard Deviation: 0.1284
#
# Code results for Koi_5652_952_540 using DataHOG features:
# Mean: 0.1069
# Standard Deviation: 0.0453
#
# Feature: DataH10
# Class Distribution:
# 2
# 4    0.209607
# 5    0.155022
# 6    0.139738
# 8    0.108079
# 7    0.102620
# 1    0.090611
# 0    0.081878
# 2    0.057860
# 3    0.054585
# dtype: float64
#
# Cross-validation scores for KNN: [0.80434783 0.79781421 0.69398907 0.75956284 0.58469945]
# Cross-validation scores for SVM: [0.82608696 0.84153005 0.73770492 0.82513661 0.60655738]
#                      Classifier  Accuracy
# 0                 Largest Prior  0.222841
# 1  Linear Discriminant Analysis  0.284123
# 2                          3-nn  0.403900
# 3                 Decision Tree  0.376045
# 4                           SVM  0.366295
# 5                       Bagging  0.433148
# 6                 Random Forest  0.461003
# 7                   KNN (tuned)  0.357939
# 8                   SVM (tuned)  0.497214
#
# Ground truth results for Koi_5652_952_540 using DataH10 features:
# Mean: 0.2740
# Standard Deviation: 0.1284
#
# Code results for Koi_5652_952_540 using DataH10 features:
# Mean: 0.3781
# Standard Deviation: 0.0853
#
# Feature: DataLBP
# Class Distribution:
# 2
# 4    0.209607
# 5    0.155022
# 6    0.139738
# 8    0.108079
# 7    0.102620
# 1    0.090611
# 0    0.081878
# 2    0.057860
# 3    0.054585
# dtype: float64
#
# Cross-validation scores for KNN: [0.4076087  0.46448087 0.3442623  0.35519126 0.35519126]
# Cross-validation scores for SVM: [0.47282609 0.51912568 0.38251366 0.4863388  0.39344262]
#                      Classifier  Accuracy
# 0                 Largest Prior  0.222841
# 1  Linear Discriminant Analysis  0.192201
# 2                          3-nn  0.186630
# 3                 Decision Tree  0.190808
# 4                           SVM  0.169916
# 5                       Bagging  0.161560
# 6                 Random Forest  0.153203
# 7                   KNN (tuned)  0.220056
# 8                   SVM (tuned)  0.160167
#
# Ground truth results for Koi_5652_952_540 using DataLBP features:
# Mean: 0.2740
# Standard Deviation: 0.1284
#
# Code results for Koi_5652_952_540 using DataLBP features:
# Mean: 0.1842
# Standard Deviation: 0.0254
#
#
# Processing Pigeons_8234_1280_720
#
# Feature: DataRGB
# Class Distribution:
# 6
# 1     0.097443
# 2     0.097443
# 3     0.097443
# 8     0.097002
# 4     0.095679
# 9     0.094797
# 11    0.094356
# 5     0.093915
# 6     0.063492
# 0     0.061287
# 12    0.057319
# 7     0.025132
# 10    0.024691
# dtype: float64
#
# Cross-validation scores for KNN: [0.44052863 0.52202643 0.61894273 0.42384106 0.27593819]
# Cross-validation scores for SVM: [0.43832599 0.53303965 0.59471366 0.4812362  0.32450331]
#                      Classifier  Accuracy
# 0                 Largest Prior  0.096943
# 1  Linear Discriminant Analysis  0.263755
# 2                          3-nn  0.317904
# 3                 Decision Tree  0.227511
# 4                           SVM  0.346725
# 5                       Bagging  0.326638
# 6                 Random Forest  0.332314
# 7                   KNN (tuned)  0.324891
# 8                   SVM (tuned)  0.256769
#
# Ground truth results for Pigeons_8234_1280_720 using DataRGB features:
# Mean: 0.2756
# Standard Deviation: 0.0986
#
# Code results for Pigeons_8234_1280_720 using DataRGB features:
# Mean: 0.2770
# Standard Deviation: 0.0789
#
# Feature: DataHOG
# Class Distribution:
# 6
# 1     0.097443
# 2     0.097443
# 3     0.097443
# 8     0.097002
# 4     0.095679
# 9     0.094797
# 11    0.094356
# 5     0.093915
# 6     0.063492
# 0     0.061287
# 12    0.057319
# 7     0.025132
# 10    0.024691
# dtype: float64
#
# Cross-validation scores for KNN: [0.35022026 0.49779736 0.6784141  0.43708609 0.39735099]
# Cross-validation scores for SVM: [0.36563877 0.5154185  0.6784141  0.49668874 0.37306843]
#                      Classifier  Accuracy
# 0                 Largest Prior  0.096943
# 1  Linear Discriminant Analysis  0.172489
# 2                          3-nn  0.244978
# 3                 Decision Tree  0.143668
# 4                           SVM  0.184279
# 5                       Bagging  0.162882
# 6                 Random Forest  0.173362
# 7                   KNN (tuned)  0.252838
# 8                   SVM (tuned)  0.186026
#
# Ground truth results for Pigeons_8234_1280_720 using DataHOG features:
# Mean: 0.2756
# Standard Deviation: 0.0986
#
# Code results for Pigeons_8234_1280_720 using DataHOG features:
# Mean: 0.1797
# Standard Deviation: 0.0477
#
# Feature: DataH10
# Class Distribution:
# 6
# 1     0.097443
# 2     0.097443
# 3     0.097443
# 8     0.097002
# 4     0.095679
# 9     0.094797
# 11    0.094356
# 5     0.093915
# 6     0.063492
# 0     0.061287
# 12    0.057319
# 7     0.025132
# 10    0.024691
# dtype: float64
#
# Cross-validation scores for KNN: [0.37444934 0.50660793 0.57488987 0.38189845 0.34216336]
# Cross-validation scores for SVM: [0.39207048 0.53964758 0.64096916 0.38631347 0.30684327]
#                      Classifier  Accuracy
# 0                 Largest Prior  0.096943
# 1  Linear Discriminant Analysis  0.370742
# 2                          3-nn  0.268996
# 3                 Decision Tree  0.200437
# 4                           SVM  0.286463
# 5                       Bagging  0.231004
# 6                 Random Forest  0.248908
# 7                   KNN (tuned)  0.281659
# 8                   SVM (tuned)  0.267249
#
# Ground truth results for Pigeons_8234_1280_720 using DataH10 features:
# Mean: 0.2756
# Standard Deviation: 0.0986
#
# Code results for Pigeons_8234_1280_720 using DataH10 features:
# Mean: 0.2503
# Standard Deviation: 0.0740
#
# Feature: DataLBP
# Class Distribution:
# 6
# 1     0.097443
# 2     0.097443
# 3     0.097443
# 8     0.097002
# 4     0.095679
# 9     0.094797
# 11    0.094356
# 5     0.093915
# 6     0.063492
# 0     0.061287
# 12    0.057319
# 7     0.025132
# 10    0.024691
# dtype: float64
#
# Cross-validation scores for KNN: [0.25991189 0.35462555 0.33480176 0.25607064 0.18763797]
# Cross-validation scores for SVM: [0.25550661 0.39207048 0.38546256 0.32891832 0.16335541]
#                      Classifier  Accuracy
# 0                 Largest Prior  0.096943
# 1  Linear Discriminant Analysis  0.191266
# 2                          3-nn  0.151528
# 3                 Decision Tree  0.179476
# 4                           SVM  0.217467
# 5                       Bagging  0.176856
# 6                 Random Forest  0.200437
# 7                   KNN (tuned)  0.185153
# 8                   SVM (tuned)  0.217467
#
# Ground truth results for Pigeons_8234_1280_720 using DataLBP features:
# Mean: 0.2756
# Standard Deviation: 0.0986
#
# Code results for Pigeons_8234_1280_720 using DataLBP features:
# Mean: 0.1796
# Standard Deviation: 0.0372
#
#
# Processing Pigeons_4927_960_540_600f
#
# Feature: DataRGB
# Class Distribution:
# 1
# 5     0.119441
# 2     0.111182
# 13    0.106734
# 6     0.095934
# 11    0.095299
# 1     0.086404
# 7     0.076874
# 8     0.073062
# 4     0.066074
# 3     0.055909
# 10    0.036213
# 12    0.033672
# 0     0.025413
# 9     0.017789
# dtype: float64
#
# Cross-validation scores for KNN: [0.34285714 0.42539683 0.51428571 0.5015873  0.44585987]
# Cross-validation scores for SVM: [0.32063492 0.49206349 0.51111111 0.63492063 0.49044586]
#                      Classifier  Accuracy
# 0                 Largest Prior  0.225806
# 1  Linear Discriminant Analysis  0.122120
# 2                          3-nn  0.099078
# 3                 Decision Tree  0.103687
# 4                           SVM  0.105223
# 5                       Bagging  0.133641
# 6                 Random Forest  0.116743
# 7                   KNN (tuned)  0.117512
# 8                   SVM (tuned)  0.126728
#
# Ground truth results for Pigeons_4927_960_540_600f using DataRGB features:
# Mean: 0.1151
# Standard Deviation: 0.0338
#
# Code results for Pigeons_4927_960_540_600f using DataRGB features:
# Mean: 0.1278
# Standard Deviation: 0.0384
#
# Feature: DataHOG
# Class Distribution:
# 1
# 5     0.119441
# 2     0.111182
# 13    0.106734
# 6     0.095934
# 11    0.095299
# 1     0.086404
# 7     0.076874
# 8     0.073062
# 4     0.066074
# 3     0.055909
# 10    0.036213
# 12    0.033672
# 0     0.025413
# 9     0.017789
# dtype: float64
#
# Cross-validation scores for KNN: [0.32698413 0.41269841 0.41587302 0.39365079 0.37579618]
# Cross-validation scores for SVM: [0.25714286 0.46666667 0.38730159 0.53333333 0.39171975]
#                      Classifier  Accuracy
# 0                 Largest Prior  0.225806
# 1  Linear Discriminant Analysis  0.126728
# 2                          3-nn  0.076805
# 3                 Decision Tree  0.098310
# 4                           SVM  0.142857
# 5                       Bagging  0.080645
# 6                 Random Forest  0.129800
# 7                   KNN (tuned)  0.090630
# 8                   SVM (tuned)  0.144393
#
# Ground truth results for Pigeons_4927_960_540_600f using DataHOG features:
# Mean: 0.1151
# Standard Deviation: 0.0338
#
# Code results for Pigeons_4927_960_540_600f using DataHOG features:
# Mean: 0.1240
# Standard Deviation: 0.0462
#
# Feature: DataH10
# Class Distribution:
# 1
# 5     0.119441
# 2     0.111182
# 13    0.106734
# 6     0.095934
# 11    0.095299
# 1     0.086404
# 7     0.076874
# 8     0.073062
# 4     0.066074
# 3     0.055909
# 10    0.036213
# 12    0.033672
# 0     0.025413
# 9     0.017789
# dtype: float64
#
# Cross-validation scores for KNN: [0.30793651 0.32698413 0.45714286 0.46666667 0.25796178]
# Cross-validation scores for SVM: [0.3047619  0.34603175 0.39365079 0.42222222 0.34076433]
#                      Classifier  Accuracy
# 0                 Largest Prior  0.225806
# 1  Linear Discriminant Analysis  0.054531
# 2                          3-nn  0.076805
# 3                 Decision Tree  0.067588
# 4                           SVM  0.092934
# 5                       Bagging  0.086022
# 6                 Random Forest  0.089094
# 7                   KNN (tuned)  0.084485
# 8                   SVM (tuned)  0.082181
#
# Ground truth results for Pigeons_4927_960_540_600f using DataH10 features:
# Mean: 0.1151
# Standard Deviation: 0.0338
#
# Code results for Pigeons_4927_960_540_600f using DataH10 features:
# Mean: 0.0955
# Standard Deviation: 0.0503
#
# Feature: DataLBP
# Class Distribution:
# 1
# 5     0.119441
# 2     0.111182
# 13    0.106734
# 6     0.095934
# 11    0.095299
# 1     0.086404
# 7     0.076874
# 8     0.073062
# 4     0.066074
# 3     0.055909
# 10    0.036213
# 12    0.033672
# 0     0.025413
# 9     0.017789
# dtype: float64
#
# Cross-validation scores for KNN: [0.19365079 0.17142857 0.21269841 0.26349206 0.22929936]
# Cross-validation scores for SVM: [0.21269841 0.19365079 0.20634921 0.3015873  0.22292994]
#                      Classifier  Accuracy
# 0                 Largest Prior  0.225806
# 1  Linear Discriminant Analysis  0.137481
# 2                          3-nn  0.109831
# 3                 Decision Tree  0.100614
# 4                           SVM  0.148233
# 5                       Bagging  0.109063
# 6                 Random Forest  0.129800
# 7                   KNN (tuned)  0.126728
# 8                   SVM (tuned)  0.148233
#
# Ground truth results for Pigeons_4927_960_540_600f using DataLBP features:
# Mean: 0.1151
# Standard Deviation: 0.0338
#
# Code results for Pigeons_4927_960_540_600f using DataLBP features:
# Mean: 0.1373
# Standard Deviation: 0.0373
#
#
# Processing Pigeons_29033_960_540_300f
#
# Feature: DataRGB
# Class Distribution:
# 19
# 1     0.069367
# 8     0.069367
# 19    0.068901
# 7     0.068901
# 14    0.068901
# 5     0.068901
# 10    0.068436
# 0     0.067970
# 13    0.060521
# 9     0.058659
# 11    0.054004
# 16    0.050745
# 2     0.047952
# 15    0.047486
# 4     0.044227
# 17    0.039106
# 12    0.020484
# 3     0.012104
# 18    0.010708
# 6     0.003259
# dtype: float64
#
# Cross-validation scores for KNN: [0.79534884 0.81162791 0.93488372 0.93240093 0.75524476]
# Cross-validation scores for SVM: [0.77209302 0.8372093  0.94651163 0.94172494 0.82983683]
#                      Classifier  Accuracy
# 0                 Largest Prior  0.066518
# 1  Linear Discriminant Analysis  0.448214
# 2                          3-nn  0.407589
# 3                 Decision Tree  0.306250
# 4                           SVM  0.426339
# 5                       Bagging  0.356250
# 6                 Random Forest  0.398661
# 7                   KNN (tuned)  0.402679
# 8                   SVM (tuned)  0.426339
#
# Ground truth results for Pigeons_29033_960_540_300f using DataRGB features:
# Mean: 0.3561
# Standard Deviation: 0.1479
#
# Code results for Pigeons_29033_960_540_300f using DataRGB features:
# Mean: 0.3599
# Standard Deviation: 0.1179
#
# Feature: DataHOG
# Class Distribution:
# 19
# 1     0.069367
# 8     0.069367
# 19    0.068901
# 7     0.068901
# 14    0.068901
# 5     0.068901
# 10    0.068436
# 0     0.067970
# 13    0.060521
# 9     0.058659
# 11    0.054004
# 16    0.050745
# 2     0.047952
# 15    0.047486
# 4     0.044227
# 17    0.039106
# 12    0.020484
# 3     0.012104
# 18    0.010708
# 6     0.003259
# dtype: float64
#
# Cross-validation scores for KNN: [0.6744186  0.78372093 0.90930233 0.92307692 0.76456876]
# Cross-validation scores for SVM: [0.65813953 0.7744186  0.92325581 0.92307692 0.74592075]
#                      Classifier  Accuracy
# 0                 Largest Prior  0.066518
# 1  Linear Discriminant Analysis  0.377232
# 2                          3-nn  0.369643
# 3                 Decision Tree  0.168304
# 4                           SVM  0.377679
# 5                       Bagging  0.258482
# 6                 Random Forest  0.273661
# 7                   KNN (tuned)  0.385268
# 8                   SVM (tuned)  0.379464
#
# Ground truth results for Pigeons_29033_960_540_300f using DataHOG features:
# Mean: 0.3561
# Standard Deviation: 0.1479
#
# Code results for Pigeons_29033_960_540_300f using DataHOG features:
# Mean: 0.2951
# Standard Deviation: 0.1143
#
# Feature: DataH10
# Class Distribution:
# 19
# 1     0.069367
# 8     0.069367
# 19    0.068901
# 7     0.068901
# 14    0.068901
# 5     0.068901
# 10    0.068436
# 0     0.067970
# 13    0.060521
# 9     0.058659
# 11    0.054004
# 16    0.050745
# 2     0.047952
# 15    0.047486
# 4     0.044227
# 17    0.039106
# 12    0.020484
# 3     0.012104
# 18    0.010708
# 6     0.003259
# dtype: float64
#
# Cross-validation scores for KNN: [0.48604651 0.61860465 0.63953488 0.63636364 0.44988345]
# Cross-validation scores for SVM: [0.53953488 0.64418605 0.59302326 0.71561772 0.44988345]
#                      Classifier  Accuracy
# 0                 Largest Prior  0.066518
# 1  Linear Discriminant Analysis  0.175446
# 2                          3-nn  0.236607
# 3                 Decision Tree  0.178125
# 4                           SVM  0.250000
# 5                       Bagging  0.214732
# 6                 Random Forest  0.243304
# 7                   KNN (tuned)  0.229018
# 8                   SVM (tuned)  0.260268
#
# Ground truth results for Pigeons_29033_960_540_300f using DataH10 features:
# Mean: 0.3561
# Standard Deviation: 0.1479
#
# Code results for Pigeons_29033_960_540_300f using DataH10 features:
# Mean: 0.2060
# Standard Deviation: 0.0602
#
# Feature: DataLBP
# Class Distribution:
# 19
# 1     0.069367
# 8     0.069367
# 19    0.068901
# 7     0.068901
# 14    0.068901
# 5     0.068901
# 10    0.068436
# 0     0.067970
# 13    0.060521
# 9     0.058659
# 11    0.054004
# 16    0.050745
# 2     0.047952
# 15    0.047486
# 4     0.044227
# 17    0.039106
# 12    0.020484
# 3     0.012104
# 18    0.010708
# 6     0.003259
# dtype: float64
#
# Cross-validation scores for KNN: [0.39302326 0.44883721 0.6372093  0.56177156 0.44755245]
# Cross-validation scores for SVM: [0.42093023 0.5255814  0.67674419 0.64568765 0.47086247]
#                      Classifier  Accuracy
# 0                 Largest Prior  0.066518
# 1  Linear Discriminant Analysis  0.300000
# 2                          3-nn  0.261161
# 3                 Decision Tree  0.192411
# 4                           SVM  0.325893
# 5                       Bagging  0.234821
# 6                 Random Forest  0.289286
# 7                   KNN (tuned)  0.287054
# 8                   SVM (tuned)  0.320982
#
# Ground truth results for Pigeons_29033_960_540_300f using DataLBP features:
# Mean: 0.3561
# Standard Deviation: 0.1479
#
# Code results for Pigeons_29033_960_540_300f using DataLBP features:
# Mean: 0.2531
# Standard Deviation: 0.0817
